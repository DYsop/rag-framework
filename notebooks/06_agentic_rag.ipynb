# %% [markdown]
# # 06 – Agentic RAG
#
# **Ziel:** Agentengestuetzte Retrieval- und Analysearchitektur.
#
# **Bezug zur Masterarbeit:** Kapitel 08 – Agentengestuetzte Architektur.
#
# **Hinweis:** Produktivcode liegt in `src/rag_framework/`. LLM-API-Keys gehoeren in `.env`.

# %% [markdown]
# ## Vorgehen
#
# 1. Agenten und Tools aus configs/agents.yaml konfigurieren.
# 2. Mehrstufige Anfragen ausfuehren.
# 3. Quellenbindung und Reasoning-Schritte pruefen.

# %%
# from rag_framework.agents import BaseAgent, Tool
# TODO: Agentengestuetzte Pipeline aufbauen und gegen Single-Pass-RAG vergleichen.
