# %% [markdown]
# # 03 – Chunking Experiments
#
# **Ziel:** Vergleich von Chunking-Strategien hinsichtlich Retrieval-Qualitaet.
#
# **Bezug zur Masterarbeit:** Kapitel 06 – Semantische Ingestion.
#
# **Hinweis:** Produktivcode liegt in `src/rag_framework/`.

# %% [markdown]
# ## Vorgehen
#
# 1. Strategien aus configs/chunking.yaml laden.
# 2. Dokumente segmentieren.
# 3. Auswirkungen auf das Retrieval vergleichen.

# %%
# from rag_framework.chunking import BaseChunker, Chunk
# TODO: Chunking-Strategien vergleichen (siehe auch chunking-viz/).
